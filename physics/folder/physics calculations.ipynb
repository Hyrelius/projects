# %%
#download libraries and thingies
import math
import numpy
import matplotlib

# %% [markdown]
# ## Calculations for the safe
# - There are two puzzles
# - One of which is a spinny rotate thingy
# - The other of which is a piezo thingy, but thats for another day

# %% [markdown]
# ### spinny rotate thingy
# solving for rotational speed, given incline mass, friction, distance needed to travel
# formulate equation and then plot values for varying mass, distance and incline and optimise for a reasonable speed
#
# $\frac{x}{y}=answer    \text{     boom equation}$

# %%
#put code here
speed = 0 # m/s
incline = 0 #some angle theta
mass = 0 #kilograms
friction = 0 #some coefficient
distance = 0 #metres
print("Hellow World")
# Out:
# Hellow World

# %%
#put plots here

# %% [markdown]
# #### wow other launcher thing here
